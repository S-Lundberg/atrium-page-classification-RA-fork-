# %%
from ra_archive_getter import ArchiveGetter
import os
import pandas as pd
from pathlib import Path
import contextlib
import io

# %%
max_pid = None
max_per_col = 6
max_per_manifest = 2 
max_images = 15

TIME = "20260417-0800"

model_path =  "C:\\RA_ufal_atrium\\atrium-page-classification-RA-fork-\\model_checkpoints\\model_ViT-B16_rev_main_10e.pt"
#model_path =  "C:\\RA_ufal_atrium\\atrium-page-classification-RA-fork-\\model_checkpoints\\model_ViT-B16_rev_main_10e.pt"
eval_path = ".\\anno"
path="anno"
out_path = "anno_tested"
csv_path = path + "\\anno_images.csv"

# %%
#running = python run.py --directory "C:\\RA-CLIP\\test_set" --model_path "C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt"  --topn 2 --eval

# %%
# --- CONFIG ---
source_dir = r".\\result\\tables"          # där datum-csv:erna ligger
master_csv = r".\\transc_new\\transc_new_images.csv"    # csv som innehåller kolumnen "image_id"
output_csv = r".\\transc_new\\transc_new_images.csv" # där den sammanslagna csv:n ska sparas (kan vara samma som master_csv)

# %%
import os
import pandas as pd

def combine_csvs(source_dir, master_csv, output_csv, min_prefix):

    # --- STEG 1: hitta alla csv-filer med datum-prefix som är senare ---
    csv_files = []
    for f in os.listdir(source_dir):
        if not f.endswith(".csv"):
            continue

        prefix = f[:13]  # YYYYMMDD-HHMM

        if prefix[8] == "-" and prefix[:8].isdigit() and prefix[9:].isdigit():
            if prefix > min_prefix:
                csv_files.append(os.path.join(source_dir, f))

    import time

    # försök hitta CSV-filer upp till N gånger
    max_retries = 5
    retry_delay = 2  # sekunder

    for attempt in range(max_retries):
        if csv_files:
            break

        print(f"⚠️  Ingen ny CSV hittad (försök {attempt+1}/{max_retries}). Väntar {retry_delay}s...")
        time.sleep(retry_delay)

        # försök igen
        csv_files = []
        for f in os.listdir(source_dir):
            if not f.endswith(".csv"):
                continue

            prefix = f[:13]
            if prefix[8] == "-" and prefix[:8].isdigit() and prefix[9:].isdigit():
                if prefix > min_prefix:
                    csv_files.append(os.path.join(source_dir, f))

    # efter retries: fortfarande inga filer
    if not csv_files:
        print("❗ Ingen CSV hittades efter flera försök. Hoppar över combine_csvs denna gång.")
        return  # eller continue om du kör i loop


    # --- STEG 2: läs och kombinera ---
    dfs = [pd.read_csv(f) for f in csv_files]
    combined = pd.concat(dfs, ignore_index=True)

    # dessa csv: FILE,PAGE,CLASS-1,CLASS-2,SCORE-1,SCORE-2
    required_cols = {"FILE", "PAGE"}
    if not required_cols.issubset(combined.columns):
        raise RuntimeError(f"Combined CSVs must contain columns: {required_cols}")

    # --- STEG 3: läs master ---
    master = pd.read_csv(master_csv)

    if "image_id" not in master.columns:
        raise RuntimeError("Master CSV must contain column: image_id")

    # --- STEG 4: bygg match_key ---
    combined["PAGE"] = combined["PAGE"].astype(int)
    combined["match_key"] = combined["FILE"].astype(str) + "_" + combined["PAGE"].astype(str).str.zfill(5)

    master["match_key"] = master["image_id"].astype(str)

    # --- STEG 5: identifiera prediction-kolumner ---
    pred_cols = [c for c in combined.columns if c not in ["FILE", "PAGE", "match_key"]]

    # skapa reducerad combined
    combined_reduced = combined[["match_key"] + pred_cols]

    # --- STEG 6: merge med suffix ---
    merged = master.merge(combined_reduced, on="match_key", how="left", suffixes=("", "_new"))

    # --- STEG 7: idempotent uppdatering ---
    for col in pred_cols:
        new_col = col + "_new"
        if new_col in merged.columns:
            # uppdatera endast där master saknar värde
            merged[col] = merged[col].combine_first(merged[new_col])
            merged = merged.drop(columns=[new_col])

    # --- STEG 8: spara ---
    merged.to_csv(output_csv, index=False)
    print("Merged CSV saved to:", output_csv)

    # --- STEG 9: radera datum-csv ---
    for f in csv_files:
        try:
            os.remove(f)
            print("Deleted:", f)
        except Exception as e:
            print("Could not delete:", f, "Error:", e)

# %%
referenskoder = [
    "SE/RA/310180",
    "SE/RA/310180A",
    "SE/RA/310181",
    "SE/RA/310182",
    "SE/RA/310183",
    "SE/RA/310184",
    "SE/RA/310185",
    "SE/RA/310186",
    "SE/RA/310187",
    "SE/RA/420422",
    "SE/HLA/1040125",
    "SE/HLA/1040161",
    "SE/HLA/1070072",
    "SE/HLA/1070112",
    "SE/KrA/0082",
    "SE/LLA/10291",
    "SE/LLA/11086",
    "SE/RA/1134",	
    "SE/RA/420096",
    "SE/SSA/0138",
    "SE/VaLA/03825",
    "SE/GLA/12703",
    "SE/GLA/11675",
    "SE/GLA/11674",
    "SE/RA/6112",
    "SE/RA/6122",
    "SE/RA/420013",
    "SE/HLA/1090014",
    "SE/HLA/1270004",
    "SE/LLA/30091",
    "SE/RA/420013",   
    "SE/RA/720767",
    "SE/RA/757",
    "SE/ULA/10101",
    "SE/ULA/10102",
]

# %%
def count_images(root):
    exts = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff", ".webp"}
    total = 0

    for path, dirs, files in os.walk(root):
        for f in files:
            if os.path.splitext(f.lower())[1] in exts:
                total += 1

    return total

# %%
params = {
#        "year_min":1000,
#        "year_max":2025,
       "limit":1000,
#        
#        "facet":"ArchivalInstitution:Riksarkivet i Täby, Krigsarkivet",
        }

# %%
#import matplotlib
#matplotlib.use('Agg')  # Använd en icke-interaktiv backend
import matplotlib.pyplot as plt 
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
import os
import shutil

def move_all_images(source_dir, target_dir, extensions=(".jpg", ".jpeg", ".png", ".tif", ".tiff")):
    """
    Letar efter alla bildfiler i source_dir och flyttar dem till target_dir.
    Skapar target_dir om den inte finns.
    Hoppar över filer som redan finns i target_dir.
    """

    # skapa mål-mapp om den saknas
    os.makedirs(target_dir, exist_ok=True)

    moved = 0
    skipped = 0

    # loopa över alla filer i source_dir
    for filename in os.listdir(source_dir):
        if not filename.lower().endswith(extensions):
            continue  # hoppa över icke-bilder

        src = os.path.join(source_dir, filename)
        dst = os.path.join(target_dir, filename)

        # om filen redan finns i target_dir → hoppa över
        if os.path.exists(dst):
            print(f"⏭️  Redan flyttad: {filename}")
            skipped += 1
            continue

        try:
            shutil.move(src, dst)
            print(f"➡️  Flyttad: {filename}")
            moved += 1
        except Exception as e:
            print(f"❌ Kunde inte flytta {filename}: {e}")

    print("\n--- Sammanfattning ---")
    print(f"Flyttade: {moved}")
    print(f"Redan flyttade: {skipped}")

# %%
from tqdm import tqdm
tqdm.disable = True

# %%
ag = ArchiveGetter()
ag.records.params = params

f = io.StringIO()
imgs_tot = 0
for ind,repref in enumerate(referenskoder):
    print(f"********************** {repref} **********************\n\n")
    with contextlib.redirect_stdout(f):
        ag.get_images(search=repref, path=path,max_total=max_images,
                max_per_manifest=max_per_manifest, max_per_collection=max_per_col, max_pids=max_pid)
    if count_images(path) >= 100:
        # !python run.py --directory {path} --model_path {model_path} --topn 2
    
        with contextlib.redirect_stdout(f):
            combine_csvs(source_dir, master_csv, output_csv, TIME)
    elif ind == len(referenskoder)-1:
        # !python run.py --directory {path} --model_path {model_path} --topn 2
    
        with contextlib.redirect_stdout(f):
            combine_csvs(source_dir, master_csv, output_csv, TIME)
        #!python anno.py --csv_path {csv_path} --output_csv {csv_path} --image_dir {path}
        #move_all_images(path, "test_images")
            imgs_tot += count_images(path)
            print(f"Total images processed: {imgs_tot}")
            #ag.remove_images(path)
            move_all_images(path,out_path)
    if imgs_tot >= 10000:
        #print("Reached 500,000 images. Stopping.")
        break
# Out:
# ********************** SE/RA/310180 **********************
#
#
# ********************** SE/RA/310180A **********************
#
#
# ********************** SE/RA/310181 **********************
#
#
# ********************** SE/RA/310182 **********************
#
#
# ********************** SE/RA/310183 **********************
#
#
# ********************** SE/RA/310184 **********************
#
#
# ********************** SE/RA/310185 **********************
#
#
# ********************** SE/RA/310186 **********************
#
#
# ********************** SE/RA/310187 **********************
#
#
# ********************** SE/RA/420422 **********************
#
#
# ********************** SE/HLA/1040125 **********************
#
#
# ********************** SE/HLA/1040161 **********************
#
#
# ********************** SE/HLA/1070072 **********************
#
#
# ********************** SE/HLA/1070112 **********************
#
#
# ********************** SE/KrA/0082 **********************
#
#
# ********************** SE/LLA/10291 **********************
# Processing batch 1/1:   0%|          | 0/115 [00:00<?, ?it/s]
# Processing batch 1/1:   1%|          | 1/115 [00:00<01:00,  1.90it/s]
# Processing batch 1/1:   2%|▏         | 2/115 [00:00<00:36,  3.09it/s]
# Processing batch 1/1:   3%|▎         | 3/115 [00:00<00:28,  3.89it/s]
# Processing batch 1/1:   3%|▎         | 4/115 [00:01<00:24,  4.53it/s]
# Processing batch 1/1:   4%|▍         | 5/115 [00:01<00:22,  4.81it/s]
# Processing batch 1/1:   5%|▌         | 6/115 [00:01<00:21,  5.06it/s]
# Processing batch 1/1:   6%|▌         | 7/115 [00:01<00:17,  6.02it/s]
# Processing batch 1/1:   7%|▋         | 8/115 [00:01<00:19,  5.48it/s]
# Processing batch 1/1:   8%|▊         | 9/115 [00:01<00:19,  5.54it/s]
# Processing batch 1/1:   9%|▊         | 10/115 [00:02<00:19,  5.43it/s]
# Processing batch 1/1:  10%|▉         | 11/115 [00:02<00:18,  5.54it/s]
# Processing batch 1/1:  10%|█         | 12/115 [00:02<00:18,  5.69it/s]
# Processing batch 1/1:  78%|███████▊  | 90/115 [00:17<00:06,  4.01it/s]
# Processing batch 1/1:  79%|███████▉  | 91/115 [00:17<00:05,  4.23it/s]
# Processing batch 1/1:  80%|████████  | 92/115 [00:18<00:05,  4.46it/s]
# Processing batch 1/1:  81%|████████  | 93/115 [00:18<00:04,  4.66it/s]
# Processing batch 1/1:  82%|████████▏ | 94/115 [00:18<00:04,  4.86it/s]
# Processing batch 1/1:  83%|████████▎ | 95/115 [00:18<00:03,  5.03it/s]
# Processing batch 1/1:  83%|████████▎ | 96/115 [00:18<00:03,  4.95it/s]
# Processing batch 1/1:  84%|████████▍ | 97/115 [00:19<00:03,  4.91it/s]
# Processing batch 1/1:  85%|████████▌ | 98/115 [00:19<00:03,  4.89it/s]
# Processing batch 1/1:  86%|████████▌ | 99/115 [00:19<00:03,  4.88it/s]
# Processing batch 1/1:  87%|████████▋ | 100/115 [00:19<00:03,  4.81it/s]
# Processing batch 1/1:  88%|████████▊ | 101/115 [00:19<00:02,  4.83it/s]
# Processing batch 1/1:  89%|████████▊ | 102/115 [00:20<00:02,  4.79it/s]
# Processing batch 1/1:  90%|████████▉ | 103/115 [00:20<00:02,  4.95it/s]
# Processing batch 1/1:  90%|█████████ | 104/115 [00:20<00:02,  5.38it/s]
# Processing batch 1/1:  91%|█████████▏| 105/115 [00:20<00:01,  5.09it/s]
# Processing batch 1/1:  92%|█████████▏| 106/115 [00:20<00:01,  5.71it/s]
# Processing batch 1/1:  93%|█████████▎| 107/115 [00:20<00:01,  5.40it/s]
# Processing batch 1/1:  94%|█████████▍| 108/115 [00:21<00:01,  4.46it/s]
# Processing batch 1/1:  95%|█████████▍| 109/115 [00:21<00:01,  4.54it/s]
# Processing batch 1/1:  96%|█████████▌| 110/115 [00:21<00:00,  5.10it/s]
# Processing batch 1/1:  97%|█████████▋| 111/115 [00:21<00:00,  4.97it/s]
# Processing batch 1/1:  97%|█████████▋| 112/115 [00:22<00:00,  4.92it/s]
# Processing batch 1/1:  98%|█████████▊| 113/115 [00:22<00:00,  4.96it/s]
# Processing batch 1/1:  99%|█████████▉| 114/115 [00:22<00:00,  5.06it/s]
# Processing batch 1/1: 100%|██████████| 115/115 [00:22<00:00,  5.17it/s]
# Processing batch 1/1: 100%|██████████| 115/115 [00:22<00:00,  5.09it/s]
# Using device: cuda
# Arguments:
# file_format 	=	 jpg
# directory 	=	 anno
# model 	=	 ViT-B/16
# epochs 	=	 8
# lr 	=	 1e-05
# batch_size 	=	 16
# max_categ 	=	 14000
# max_categ_eval 	=	 3000
# cat_prefix 	=	 page_categories
# cat_csv 	=	 ./category_descriptions/ENG_page_categories.csv
# cat_dir 	=	 ./category_descriptions
# prompt_path 	=	 ./category_descriptions/prompts/test_set_prompts.tsv
# metadata_path 	=	 C:\\RA-CLIP\\Dataset_03_24\trying_images.csv
# image_features 	=	 C:\\RA_ufal_atrium\\atrium-page-classification-RA-fork-\\features
# topn 	=	 2
# model_path 	=	 C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# model_dir 	=	 ./models
# revision 	=	 main
# logdir 	=	 logs\run.py-2026-04-17_104927-as=False,a=False,bs=16,b=False,c=False,e=False,e=8,is=False,l=1e-05,mc=14000,mce=3000,pe=False,r=main,t=2,zs=False-ViT-B_16
# Chosen file handling:	jpg format
# 	Safety load of images:	True
# Loaded 9 categories from c:\RA_ufal_atrium\atrium-page-classification-RA-fork-\category_descriptions\ENG_page_categories.csv
# Categories: ['DRAW', 'LINE_HW', 'LINE_MIX', 'LINE_TP', 'MISC', 'PHOTO', 'TEXT', 'TEXT_HW', 'TEXT_TP'] with single description per category.
# Category: DRAW, Descriptions:
#   - A page containing a drawing, map, painting, or schematic with text labels
#   - A page with a drawing or map presented in table form or with a table legend
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with labels on a document page
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with an accompanying table or table legend on a document page
#   - A page containing drawings, maps, paintings, schematics, or graphics
#   - A page with drawings or maps presented in table form
#   - Drawings, maps, or diagrams
#   - A table or table legend together with drawings, maps, or diagrams
#   - Drawings, maps, paintings, schematics, or graphics with labels
#   - Drawings, maps, paintings, schematics, or graphics with a table legend, in a table or form
# Category: LINE_HW, Descriptions:
#   - A page with handwritten text in table form or a manually filled-in form
#   - A table or completed form with handwritten text rows on a document page
#   - A table or completed form with handwritten text
#   - A table or completed form with handwritten cells
#   - A handwritten table or a filled-in form
#   - A document page with handwritten table rows and manually filled fields
#   - A form with handwritten entries organized in rows and columns
#   - A page with structured handwritten information in table format
#   - A document with handwritten cells and manually filled table structures
#   - A table-based document page with handwritten notes in each row
# Category: LINE_TP, Descriptions:
#   - A page with printed text in table form or a large printed table filling the entire page
#   - A page with typewritten text in table form or a form filled with typewritten text
#   - A table or completed form with printed text rows on a document page
#   - A table or completed form with typewritten text rows on a document page
#   - A table or completed form with printed cells
#   - A table or completed form with typewritten cells
#   - A printed table or a completed form
#   - A typewritten table or a completed form
#   - A document page with printed table rows and typewritten cells
#   - A structured form with printed or typewritten entries in table format
# Category: PHOTO, Descriptions:
#   - A page with a photograph or photographic image with text labels
#   - A page with a photograph presented in table form or with a table legend
#   - A photo or photo clipping with labels attached to a document page
#   - A photo or photo clipping with an accompanying table or table legend on a document page
#   - Photographs or photo clippings attached to a document page
#   - Photographs or photo clippings with a table or table legend
#   - Photographs or photo clippings on a page
#   - Photographs or photo clippings together with a table
#   - A document page with photographs accompanied by labels or captions
#   - A photographic subject placed in a table-like or form-like layout
# Category: TEXT, Descriptions:
#   - A page with mixed handwritten, printed, or typewritten text, such as a book or newspaper page with handwritten comments
#   - A document page with mixed printed and handwritten text styles
#   - A page with mixed text styles
#   - Printed and handwritten text on a page
#   - A document page with varying text styles and mixed text blocks
#   - A page with both printed and handwritten text elements in running form
#   - A mixed text page with multiple types of text presentation
#   - A document page where different text styles are combined in the same layout
#   - A page with text in multiple formats, such as marginal notes and main text
#   - A document page with both structured and unstructured text
# Category: TEXT_HW, Descriptions:
#   - A page with only handwritten text in paragraphs, such as field diaries or notebooks
#   - Handwritten running text, handwritten paragraphs, or handwritten lists on a document page
#   - A page with handwritten text
#   - A handwritten text page
#   - A document page with continuous handwritten text in running form
#   - A page with handwritten notes organized in paragraphs
#   - A text page with handwritten sentences and longer text blocks
#   - A document page with handwritten lines in running text format
#   - A page with handwritten text sections and marginal notes
#   - A text page with dense handwriting and continuous text
# Category: TEXT_TP, Descriptions:
#   - A page with only printed text in paragraphs, lists, or continuous prose, such as an article page or book scan
#   - A page with only typewritten text in paragraphs, lists, or continuous prose, such as older field reports
#   - Printed continuous text, printed paragraphs, or printed lists on a document page
#   - Typewritten continuous text, typewritten paragraphs, or typewritten lists on a document page
#   - A printed text page
#   - A typewritten text page
#   - A typewritten document page
#   - A document page with printed or typewritten continuous text in structured blocks
#   - A document page with clean printed text without handwritten elements
# Category: LINE_MIX, Descriptions:
#   - A table or completed form with mixed handwritten, printed, and typewritten text rows
#   - A document page with mixed text styles in table form or structured form
#   - A page with handwritten, printed, and typewritten entries mixed in the same table
#   - A form filled with a combination of handwritten, printed, and typewritten text
#   - A table with mixed text styles in rows and columns
#   - A structured document page with mixed handwritten, printed, and typewritten notes
#   - A page with mixed text entries organized in a table or form
#   - A document page with rows of mixed text styles
#   - A table page with heterogeneous text styles in each row
#   - A table or form where handwritten, printed, and typewritten text is mixed in the same structure
# Category: MISC, Descriptions:
#   - A mixed document page such as a cover, title page, or front matter
#   - A document page with paratextual material or non-content elements
#   - A page such as a book cover, spine, or series title page with minimal text
#   - An archival page with decorative or structural elements rather than content
#   - A front matter or paratext page outside the document's main content
#   - A document page with non-textual or non-content elements
#   - A volume cover page or title page with sparse or irregular text
#   - A mixed page with layout elements rather than content text
#   - A paratextual or decorative document page outside the main text
#   - A document page with mixed elements not belonging to the document's primary content
# 	Number of prediction classes: 9
# 	Model name: ViT-B/16
# 	Model code name: ViT-B16_main
# Category input directories found: ["DRAW", "LINE_MIX", "LINE_HW", "LINE_TP", "PHOTO", "TEXT", "TEXT_HW", "TEXT_TP","MISC"]
# Working with a local folder 	C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# Model checkpoints folder 	model_checkpoints\model_ViT-B16_rev_main_10e_8e.pt
# Model path provided: C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# [ JPG ] 	From directory anno collected 115 jpg files
# Found 115 images in anno
# Processing 115 images with top_N=2 predictions of 9 possible labels...
# Final prediction array shape: (115, 9)
# Created results table with 115 rows and columns: ['FILE', 'PAGE', 'CLASS-1', 'CLASS-2', 'SCORE-1', 'SCORE-2']
# Results for TOP-2 predictions (115 images) saved to c:\RA_ufal_atrium\atrium-page-classification-RA-fork-\result/tables/20260417-1049_115_result_ViT-B16_main_TOP-2.csv
# ********************** SE/LLA/11086 **********************
# Processing batch 1/1:   0%|          | 0/131 [00:00<?, ?it/s]
# Processing batch 1/1:   1%|          | 1/131 [00:00<00:35,  3.62it/s]
# Processing batch 1/1:  90%|█████████ | 118/131 [00:21<00:02,  5.29it/s]
# Processing batch 1/1:  91%|█████████ | 119/131 [00:21<00:02,  4.99it/s]
# Processing batch 1/1:  92%|█████████▏| 120/131 [00:22<00:02,  5.26it/s]
# Processing batch 1/1:  92%|█████████▏| 121/131 [00:22<00:02,  4.03it/s]
# Processing batch 1/1:  94%|█████████▍| 123/131 [00:22<00:01,  5.25it/s]
# Processing batch 1/1:  95%|█████████▍| 124/131 [00:22<00:01,  5.36it/s]
# Processing batch 1/1:  95%|█████████▌| 125/131 [00:22<00:01,  5.41it/s]
# Processing batch 1/1:  97%|█████████▋| 127/131 [00:23<00:00,  6.16it/s]
# Processing batch 1/1:  98%|█████████▊| 128/131 [00:23<00:00,  6.21it/s]
# Processing batch 1/1:  98%|█████████▊| 129/131 [00:23<00:00,  6.28it/s]
# Processing batch 1/1:  99%|█████████▉| 130/131 [00:23<00:00,  6.41it/s]
# Processing batch 1/1: 100%|██████████| 131/131 [00:23<00:00,  6.49it/s]
# Processing batch 1/1: 100%|██████████| 131/131 [00:23<00:00,  5.49it/s]
# Using device: cuda
# Arguments:
# file_format 	=	 jpg
# directory 	=	 anno
# model 	=	 ViT-B/16
# epochs 	=	 8
# lr 	=	 1e-05
# batch_size 	=	 16
# max_categ 	=	 14000
# max_categ_eval 	=	 3000
# cat_prefix 	=	 page_categories
# cat_csv 	=	 ./category_descriptions/ENG_page_categories.csv
# cat_dir 	=	 ./category_descriptions
# prompt_path 	=	 ./category_descriptions/prompts/test_set_prompts.tsv
# metadata_path 	=	 C:\\RA-CLIP\\Dataset_03_24\trying_images.csv
# image_features 	=	 C:\\RA_ufal_atrium\\atrium-page-classification-RA-fork-\\features
# topn 	=	 2
# model_path 	=	 C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# model_dir 	=	 ./models
# revision 	=	 main
# logdir 	=	 logs\run.py-2026-04-17_105034-as=False,a=False,bs=16,b=False,c=False,e=False,e=8,is=False,l=1e-05,mc=14000,mce=3000,pe=False,r=main,t=2,zs=False-ViT-B_16
# Chosen file handling:	jpg format
# 	Safety load of images:	True
# Loaded 9 categories from c:\RA_ufal_atrium\atrium-page-classification-RA-fork-\category_descriptions\ENG_page_categories.csv
# Categories: ['DRAW', 'LINE_HW', 'LINE_MIX', 'LINE_TP', 'MISC', 'PHOTO', 'TEXT', 'TEXT_HW', 'TEXT_TP'] with single description per category.
# Category: DRAW, Descriptions:
#   - A page containing a drawing, map, painting, or schematic with text labels
#   - A page with a drawing or map presented in table form or with a table legend
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with labels on a document page
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with an accompanying table or table legend on a document page
#   - A page containing drawings, maps, paintings, schematics, or graphics
#   - A page with drawings or maps presented in table form
#   - Drawings, maps, or diagrams
#   - A table or table legend together with drawings, maps, or diagrams
#   - Drawings, maps, paintings, schematics, or graphics with labels
#   - Drawings, maps, paintings, schematics, or graphics with a table legend, in a table or form
# Category: LINE_HW, Descriptions:
#   - A page with handwritten text in table form or a manually filled-in form
#   - A table or completed form with handwritten text rows on a document page
#   - A table or completed form with handwritten text
#   - A table or completed form with handwritten cells
#   - A handwritten table or a filled-in form
#   - A document page with handwritten table rows and manually filled fields
#   - A form with handwritten entries organized in rows and columns
#   - A page with structured handwritten information in table format
#   - A document with handwritten cells and manually filled table structures
#   - A table-based document page with handwritten notes in each row
# Category: LINE_TP, Descriptions:
#   - A page with printed text in table form or a large printed table filling the entire page
#   - A page with typewritten text in table form or a form filled with typewritten text
#   - A table or completed form with printed text rows on a document page
#   - A table or completed form with typewritten text rows on a document page
#   - A table or completed form with printed cells
#   - A table or completed form with typewritten cells
#   - A printed table or a completed form
#   - A typewritten table or a completed form
#   - A document page with printed table rows and typewritten cells
#   - A structured form with printed or typewritten entries in table format
# Category: PHOTO, Descriptions:
#   - A page with a photograph or photographic image with text labels
#   - A page with a photograph presented in table form or with a table legend
#   - A photo or photo clipping with labels attached to a document page
#   - A photo or photo clipping with an accompanying table or table legend on a document page
#   - Photographs or photo clippings attached to a document page
#   - Photographs or photo clippings with a table or table legend
#   - Photographs or photo clippings on a page
#   - Photographs or photo clippings together with a table
#   - A document page with photographs accompanied by labels or captions
#   - A photographic subject placed in a table-like or form-like layout
# Category: TEXT, Descriptions:
#   - A page with mixed handwritten, printed, or typewritten text, such as a book or newspaper page with handwritten comments
#   - A document page with mixed printed and handwritten text styles
#   - A page with mixed text styles
#   - Printed and handwritten text on a page
#   - A document page with varying text styles and mixed text blocks
#   - A page with both printed and handwritten text elements in running form
#   - A mixed text page with multiple types of text presentation
#   - A document page where different text styles are combined in the same layout
#   - A page with text in multiple formats, such as marginal notes and main text
#   - A document page with both structured and unstructured text
# Category: TEXT_HW, Descriptions:
#   - A page with only handwritten text in paragraphs, such as field diaries or notebooks
#   - Handwritten running text, handwritten paragraphs, or handwritten lists on a document page
#   - A page with handwritten text
#   - A handwritten text page
#   - A document page with continuous handwritten text in running form
#   - A page with handwritten notes organized in paragraphs
#   - A text page with handwritten sentences and longer text blocks
#   - A document page with handwritten lines in running text format
#   - A page with handwritten text sections and marginal notes
#   - A text page with dense handwriting and continuous text
# Category: TEXT_TP, Descriptions:
#   - A page with only printed text in paragraphs, lists, or continuous prose, such as an article page or book scan
#   - A page with only typewritten text in paragraphs, lists, or continuous prose, such as older field reports
#   - Printed continuous text, printed paragraphs, or printed lists on a document page
#   - Typewritten continuous text, typewritten paragraphs, or typewritten lists on a document page
#   - A printed text page
#   - A typewritten text page
#   - A typewritten document page
#   - A document page with printed or typewritten continuous text in structured blocks
#   - A document page with clean printed text without handwritten elements
# Category: LINE_MIX, Descriptions:
#   - A table or completed form with mixed handwritten, printed, and typewritten text rows
#   - A document page with mixed text styles in table form or structured form
#   - A page with handwritten, printed, and typewritten entries mixed in the same table
#   - A form filled with a combination of handwritten, printed, and typewritten text
#   - A table with mixed text styles in rows and columns
#   - A structured document page with mixed handwritten, printed, and typewritten notes
#   - A page with mixed text entries organized in a table or form
#   - A document page with rows of mixed text styles
#   - A table page with heterogeneous text styles in each row
#   - A table or form where handwritten, printed, and typewritten text is mixed in the same structure
# Category: MISC, Descriptions:
#   - A mixed document page such as a cover, title page, or front matter
#   - A document page with paratextual material or non-content elements
#   - A page such as a book cover, spine, or series title page with minimal text
#   - An archival page with decorative or structural elements rather than content
#   - A front matter or paratext page outside the document's main content
#   - A document page with non-textual or non-content elements
#   - A volume cover page or title page with sparse or irregular text
#   - A mixed page with layout elements rather than content text
#   - A paratextual or decorative document page outside the main text
#   - A document page with mixed elements not belonging to the document's primary content
# 	Number of prediction classes: 9
# 	Model name: ViT-B/16
# 	Model code name: ViT-B16_main
# Category input directories found: ["DRAW", "LINE_MIX", "LINE_HW", "LINE_TP", "PHOTO", "TEXT", "TEXT_HW", "TEXT_TP","MISC"]
# Working with a local folder 	C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# Model checkpoints folder 	model_checkpoints\model_ViT-B16_rev_main_10e_8e.pt
# Model path provided: C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# [ JPG ] 	From directory anno collected 131 jpg files
# Found 131 images in anno
# Processing 131 images with top_N=2 predictions of 9 possible labels...
# Final prediction array shape: (131, 9)
# Created results table with 131 rows and columns: ['FILE', 'PAGE', 'CLASS-1', 'CLASS-2', 'SCORE-1', 'SCORE-2']
# Results for TOP-2 predictions (131 images) saved to c:\RA_ufal_atrium\atrium-page-classification-RA-fork-\result/tables/20260417-1050_131_result_ViT-B16_main_TOP-2.csv
# ********************** SE/RA/1134 **********************
# Processing batch 1/1:   0%|          | 0/146 [00:00<?, ?it/s]
# Processing batch 1/1:   1%|          | 1/146 [00:00<00:54,  2.65it/s]
# Processing batch 1/1:   1%|▏         | 2/146 [00:00<00:36,  3.91it/s]
# Processing batch 1/1:   2%|▏         | 3/146 [00:00<00:29,  4.88it/s]
# Processing batch 1/1:   3%|▎         | 4/146 [00:00<00:26,  5.37it/s]
# Processing batch 1/1:   3%|▎         | 5/146 [00:01<00:25,  5.56it/s]
# Processing batch 1/1:   4%|▍         | 6/146 [00:01<00:23,  5.90it/s]
# Processing batch 1/1:   5%|▌         | 8/146 [00:01<00:20,  6.72it/s]
# Processing batch 1/1:   6%|▌         | 9/146 [00:01<00:20,  6.67it/s]
# Processing batch 1/1:   7%|▋         | 10/146 [00:01<00:20,  6.66it/s]
# Processing batch 1/1:   8%|▊         | 11/146 [00:02<00:26,  5.04it/s]
# Processing batch 1/1:   8%|▊         | 12/146 [00:02<00:24,  5.39it/s]
# Processing batch 1/1:   9%|▉         | 13/146 [00:02<00:25,  5.29it/s]
# Processing batch 1/1:  10%|▉         | 14/146 [00:02<00:22,  5.96it/s]
# Processing batch 1/1:  10%|█         | 15/146 [00:02<00:24,  5.43it/s]
# Processing batch 1/1:  11%|█         | 16/146 [00:02<00:25,  5.11it/s]
# Processing batch 1/1:  89%|████████▉ | 130/146 [00:24<00:03,  4.89it/s]
# Processing batch 1/1:  90%|████████▉ | 131/146 [00:24<00:03,  4.98it/s]
# Processing batch 1/1:  90%|█████████ | 132/146 [00:24<00:02,  5.12it/s]
# Processing batch 1/1:  91%|█████████ | 133/146 [00:24<00:02,  5.19it/s]
# Processing batch 1/1:  92%|█████████▏| 134/146 [00:24<00:02,  4.18it/s]
# Processing batch 1/1:  92%|█████████▏| 135/146 [00:25<00:02,  3.73it/s]
# Processing batch 1/1:  93%|█████████▎| 136/146 [00:25<00:02,  4.13it/s]
# Processing batch 1/1:  94%|█████████▍| 137/146 [00:25<00:01,  4.63it/s]
# Processing batch 1/1:  95%|█████████▍| 138/146 [00:25<00:01,  4.03it/s]
# Processing batch 1/1:  95%|█████████▌| 139/146 [00:26<00:01,  4.35it/s]
# Processing batch 1/1:  96%|█████████▌| 140/146 [00:26<00:01,  4.67it/s]
# Processing batch 1/1:  97%|█████████▋| 141/146 [00:26<00:01,  4.43it/s]
# Processing batch 1/1:  97%|█████████▋| 142/146 [00:26<00:00,  4.25it/s]
# Processing batch 1/1:  98%|█████████▊| 143/146 [00:27<00:00,  4.26it/s]
# Processing batch 1/1:  99%|█████████▊| 144/146 [00:27<00:00,  4.57it/s]
# Processing batch 1/1:  99%|█████████▉| 145/146 [00:27<00:00,  4.85it/s]
# Processing batch 1/1: 100%|██████████| 146/146 [00:27<00:00,  5.04it/s]
# Processing batch 1/1: 100%|██████████| 146/146 [00:27<00:00,  5.29it/s]
# Using device: cuda
# Arguments:
# file_format 	=	 jpg
# directory 	=	 anno
# model 	=	 ViT-B/16
# epochs 	=	 8
# lr 	=	 1e-05
# batch_size 	=	 16
# max_categ 	=	 14000
# max_categ_eval 	=	 3000
# cat_prefix 	=	 page_categories
# cat_csv 	=	 ./category_descriptions/ENG_page_categories.csv
# cat_dir 	=	 ./category_descriptions
# prompt_path 	=	 ./category_descriptions/prompts/test_set_prompts.tsv
# metadata_path 	=	 C:\\RA-CLIP\\Dataset_03_24\trying_images.csv
# image_features 	=	 C:\\RA_ufal_atrium\\atrium-page-classification-RA-fork-\\features
# topn 	=	 2
# model_path 	=	 C:\RA_ufal_atrium\atrium-page-classification-RA-fork-\model_checkpoints\model_ViT-B16_rev_main_10e.pt
# model_dir 	=	 ./models
# revision 	=	 main
# logdir 	=	 logs\run.py-2026-04-17_105156-as=False,a=False,bs=16,b=False,c=False,e=False,e=8,is=False,l=1e-05,mc=14000,mce=3000,pe=False,r=main,t=2,zs=False-ViT-B_16
# Chosen file handling:	jpg format
# 	Safety load of images:	True
# Loaded 9 categories from c:\RA_ufal_atrium\atrium-page-classification-RA-fork-\category_descriptions\ENG_page_categories.csv
# Categories: ['DRAW', 'LINE_HW', 'LINE_MIX', 'LINE_TP', 'MISC', 'PHOTO', 'TEXT', 'TEXT_HW', 'TEXT_TP'] with single description per category.
# Category: DRAW, Descriptions:
#   - A page containing a drawing, map, painting, or schematic with text labels
#   - A page with a drawing or map presented in table form or with a table legend
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with labels on a document page
#   - A drawing, map, painting, sketch, diagram, schematic, or graphic figure with an accompanying table or table legend on a document page
#   - A page containing drawings, maps, paintings, schematics, or graphics
#   - A page with drawings or maps presented in table form
#   - Drawings, maps, or diagrams
#   - A table or table legend together with drawings, maps, or diagrams
#   - Drawings, maps, paintings, schematics, or graphics with labels
#   - Drawings, maps, paintings, schematics, or graphics with a table legend, in a table or form
# Category: LINE_HW, Descriptions:
#   - A page with handwritten text in table form or a manually filled-in form
#   - A table or completed form with handwritten text rows on a document page
#   - A table or completed form with handwritten text
#   - A table or completed form with handwritten cells
#   - A handwritten table or a filled-in form
#   - A document page with handwritten table rows and manually filled fields
#   - A form with handwritten entries organized in rows and columns
#   - A page with structured handwritten information in table format
#   - A document with handwritten cells and manually filled table structures
#   - A table-based document page with handwritten notes in each row
# Category: LINE_TP, Descriptions:
#   - A page with printed text in table form or a large printed table filling the entire page
#   - A page with typewritten text in table form or a form filled with typewritten text
#   - A table or completed form with printed text rows on a document page
# ...
# Processing batch 1/1:  35%|███▌      | 125/355 [00:29<01:19,  2.88it/s]
# Processing batch 1/1:  35%|███▌      | 126/355 [00:30<01:13,  3.12it/s]
# Processing batch 1/1:  36%|███▌      | 127/355 [00:30<00:59,  3.83it/s]
# Processing batch 1/1:  36%|███▌      | 128/355 [00:30<00:59,  3.84it/s]
# Processing batch 1/1:  36%|███▋      | 129/355 [00:30<00:49,  4.58it/s]
# Processing batch 1/1:  37%|███▋      | 130/355 [00:30<00:42,  5.30it/s]
# Processing batch 1/1:  37%|███▋      | 131/355 [00:31<00:45,  4.90it/s]
# Processing batch 1/1:  37%|███▋      | 132/355 [00:31<00:48,  4.58it/s]
# Processing batch 1/1:  37%|███▋      | 133/355 [00:31<00:49,  4.50it/s]
# Processing batch 1/1:  38%|███▊      | 134/355 [00:31<00:49,  4.45it/s]
# Processing batch 1/1:  38%|███▊      | 135/355 [00:32<00:51,  4.31it/s]
# Processing batch 1/1:  38%|███▊      | 136/355 [00:32<00:51,  4.22it/s]
# Processing batch 1/1:  39%|███▊      | 137/355 [00:32<00:51,  4.25it/s]
# Processing batch 1/1:  39%|███▉      | 138/355 [00:32<00:54,  3.97it/s]
# Processing batch 1/1:  39%|███▉      | 139/355 [00:33<00:54,  4.00it/s]
# Processing batch 1/1:  39%|███▉      | 140/355 [00:33<00:54,  3.97it/s]
# Processing batch 1/1:  40%|███▉      | 141/355 [00:33<00:53,  4.03it/s]
# Processing batch 1/1:  40%|████      | 142/355 [00:33<00:52,  4.08it/s]
# Processing batch 1/1:  40%|████      | 143/355 [00:34<00:55,  3.82it/s]
# Processing batch 1/1:  41%|████      | 144/355 [00:34<00:57,  3.68it/s]
# Processing batch 1/1:  41%|████      | 145/355 [00:34<00:56,  3.73it/s]
# Processing batch 1/1:  41%|████      | 146/355 [00:35<01:00,  3.43it/s]
# Processing batch 1/1:  41%|████▏     | 147/355 [00:35<01:00,  3.43it/s]
# Processing batch 1/1:  94%|█████████▍| 334/355 [01:13<00:05,  3.70it/s]
# Processing batch 1/1:  94%|█████████▍| 335/355 [01:13<00:05,  3.79it/s]
# Processing batch 1/1:  95%|█████████▍| 336/355 [01:13<00:04,  3.89it/s]
# Processing batch 1/1:  95%|█████████▍| 337/355 [01:13<00:04,  3.71it/s]
# Processing batch 1/1:  95%|█████████▌| 338/355 [01:14<00:04,  3.70it/s]
# Processing batch 1/1:  95%|█████████▌| 339/355 [01:14<00:04,  3.54it/s]
# Processing batch 1/1:  96%|█████████▌| 340/355 [01:14<00:04,  3.58it/s]
# Processing batch 1/1:  96%|█████████▌| 341/355 [01:14<00:03,  3.89it/s]
# Processing batch 1/1:  96%|█████████▋| 342/355 [01:15<00:03,  4.19it/s]
# Processing batch 1/1:  97%|█████████▋| 343/355 [01:15<00:02,  4.32it/s]
# Processing batch 1/1:  97%|█████████▋| 344/355 [01:15<00:02,  4.29it/s]
# Processing batch 1/1:  97%|█████████▋| 345/355 [01:15<00:02,  4.25it/s]
# Processing batch 1/1:  97%|█████████▋| 346/355 [01:16<00:02,  4.26it/s]
# Processing batch 1/1:  98%|█████████▊| 347/355 [01:16<00:01,  4.39it/s]
# Processing batch 1/1:  98%|█████████▊| 348/355 [01:16<00:01,  4.47it/s]
# Processing batch 1/1:  98%|█████████▊| 349/355 [01:16<00:01,  4.52it/s]
# Processing batch 1/1:  99%|█████████▊| 350/355 [01:16<00:01,  4.53it/s]
# Processing batch 1/1:  99%|█████████▉| 351/355 [01:17<00:00,  4.17it/s]
# Processing batch 1/1:  99%|█████████▉| 352/355 [01:17<00:00,  4.22it/s]
# Processing batch 1/1:  99%|█████████▉| 353/355 [01:17<00:00,  4.50it/s]
# Processing batch 1/1: 100%|█████████▉| 354/355 [01:17<00:00,  4.49it/s]
# Processing batch 1/1: 100%|██████████| 355/355 [01:17<00:00,  4.61it/s]
# Processing batch 1/1: 100%|██████████| 355/355 [01:17<00:00,  4.55it/s]

# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

csv_path = output_csv

df = pd.read_csv(csv_path)
df = df.drop_duplicates(subset=["image_id"])
# --- CLASS histogram ---
plt.figure(figsize=(10, 6))
for i,j in enumerate(df["CLASS-1"].value_counts().values[:2]):
    plt.axhline(j,color="black", linestyle="dashed", alpha=0.5)
    plt.text(df["CLASS-1"].value_counts().index[i], j+5, f"{j}", ha="center", va="bottom", color="black", fontsize=10)
sns.histplot(
    data=df,
    x="CLASS-1",
    hue="CLASS-2",
    multiple="stack",
    shrink=0.8
)
plt.title("Stacked Histogram: CLASS-1 + CLASS-2")
plt.xlabel("Class")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# --- SCORE histogram ---
plt.figure(figsize=(10, 6))


sns.histplot(
    data=df.melt(value_vars=["SCORE-1", "SCORE-2"], var_name="score_type", value_name="score"),
    x="score",
    hue="score_type",
    multiple="stack",
    bins=30,
    shrink=0.8
)
plt.title("Stacked Histogram: SCORE-1 + SCORE-2")
plt.xlabel("Score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
